# %%
import pandas as pd
import numpy as np
import boto3
from sklearn.model_selection import train_test_split
import sagemaker
from sagemaker import Session
import io
import sagemaker.amazon.common as smac
import os
from sagemaker.amazon.amazon_estimator import get_image_uri
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
df = pd.read_csv("student_scores.csv")
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.shape
# Out:
# (25, 2)

# %%
# seperate x and y
x = df["Hours"]
y = df["Scores"]

# %%
x.dtypes
y.dtypes
# Out:
# dtype('int64')

# %%
x = x.astype("float32")
y = y.astype("float32")

# %%
# split the data 
X_train,X_test,y_train,y_test =train_test_split(x,y,test_size=0.2)

# %%
X_train = X_train.reset_index(drop=True)
X_test =  X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test =  y_test.reset_index(drop=True)

# %%
import numpy as np

print("X_train:", type(X_train), getattr(X_train, "shape", None), getattr(X_train, "dtype", None))
print("y_train:", type(y_train), getattr(y_train, "shape", None), getattr(y_train, "dtype", None))
# Out:
# X_train: <class 'pandas.core.series.Series'> (20,) float32
# y_train: <class 'pandas.core.series.Series'> (20,) float32

# %%
# Ensure correct shapes/dtypes
X_train = np.asarray(X_train, dtype=np.float32).reshape(-1, 1)  # (20,) -> (20, 1)
y_train = np.asarray(y_train, dtype=np.float32).ravel()         # Series -> ndarray (20,)

# %%
y_train
# Out:
# array([30., 75., 81., 17., 42., 62., 88., 54., 41., 69., 67., 60., 30.,
#        47., 95., 76., 35., 20., 27., 30.], dtype=float32)

# %%
# lets create sagemaker session
sagemaker_session = sagemaker.Session()
#define the bucket name
bucket_name = "shubhamaws-bucket"
# define the prefix
prefix = "linear_learner"
# get the execution role
role = sagemaker.get_execution_role()
role
# Out:
# 'arn:aws:iam::919751357950:role/service-role/AmazonSageMaker-ExecutionRole-20260112T120635'

# %%
# convert X_train into numpy array
X_train = np.array(X_train)
X_train
# Out:
# array([[2.5],
#        [8.5],
#        [8.3],
#        [1.1],
#        [3.3],
#        [5.9],
#        [9.2],
#        [4.8],
#        [4.5],
#        [7.4],
#        [6.1],
#        [5.5],
#        [3.5],
#        [5.1],
#        [8.9],
#        [6.9],
#        [3.8],
#        [1.5],
#        [3.2],
#        [2.7]], dtype=float32)

# %%
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf,X_train,y_train)
buf.seek(0)
# Out:
# 0

# %%
# define the name of the file
key = "students-data"

#code to upload in s3
boto3.resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'train',key)).upload_fileobj(buf)

# path of our data
s3_train_data = f"s3://{bucket_name}/{prefix}/train/{key}"

print("Data uploaded",s3_train_data)
buf.close()
# Out:
# Data uploaded s3://shubhamaws-bucket/linear_learner/train/students-data

# %%
# Ensure correct shapes/dtypes
X_test = np.asarray(X_test, dtype=np.float32).reshape(-1, 1)  # (20,) -> (20, 1)
y_test = np.asarray(y_test, dtype=np.float32).ravel()         # Series -> ndarray (20,)

# %%
# convert X_train into numpy array
X_test = np.array(X_test)
X_test
# Out:
# array([[2.7],
#        [7.7],
#        [7.8],
#        [1.9],
#        [2.5]], dtype=float32)

# %%
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf,X_test,y_test)
buf.seek(0)
# Out:
# 0

# %%
# define the name of the file
key = "students-data-test"

#code to upload in s3
boto3.resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'test',key)).upload_fileobj(buf)

# path of our data
s3_test_data = f"s3://{bucket_name}/{prefix}/test/{key}"

print("Data uploaded",s3_test_data)
# Out:
# Data uploaded s3://shubhamaws-bucket/linear_learner/test/students-data-test

# %%
output_location = f"s3://{bucket_name}/{prefix}/output"
output_location
# Out:
# 's3://shubhamaws-bucket/linear_learner/output'

# %%
#bring the container
container = sagemaker.image_uris.retrieve("linear-learner",boto3.Session().region_name)

# %%
#define the estimator
linear=sagemaker.estimator.Estimator(container,role=role,instance_count =1,instance_type="ml.c5.xlarge",output_path=output_location,sagemaker_session=sagemaker_session)

# %%
# setting up the hyperparameters
linear.set_hyperparameters(feature_dim=1,predictor_type="regressor",mini_batch_size=4,epochs=6,num_models=32,loss="absolute_loss")

# %%
linear.fit({"train":s3_test_data})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2026-01-29-10-02-09-333
# 2026-01-29 10:02:12 Starting - Starting the training job...
# 2026-01-29 10:02:28 Starting - Preparing the instances for training...
# 2026-01-29 10:03:09 Downloading - Downloading the training image.........
# 2026-01-29 10:04:40 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/29/2026 10:04:44 INFO 140651495421760] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [01/29/2026 10:04:44 INFO 140651495421760] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '6', 'feature_dim': '1', 'loss': 'absolute_loss', 'mini_batch_size': '4', 'num_models': '32', 'predictor_type': 'regressor'}
# [01/29/2026 10:04:44 INFO 140651495421760] Final configuration: {'mini_batch_size': '4', 'epochs': '6', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [01/29/2026 10:04:47 WARNING 140651495421760] Loggers have already been setup.
# [01/29/2026 10:04:47 INFO 140651495421760] Final configuration: {'mini_batch_size': '4', 'epochs': '6', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [01/29/2026 10:04:47 WARNING 140651495421760] Loggers have already been setup.
# Process 7 is a worker.
# [01/29/2026 10:04:47 INFO 140651495421760] Using default worker.
# [01/29/2026 10:04:47 INFO 140651495421760] Checkpoint loading and saving are disabled.
# [2026-01-29 10:04:47.153] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 10, "num_examples": 1, "num_bytes": 192}
# [01/29/2026 10:04:47 INFO 140651495421760] Create Store: local
# [2026-01-29 10:04:47.164] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 10, "num_examples": 2, "num_bytes": 240}
# [01/29/2026 10:04:47 INFO 140651495421760] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7feb6a1bd2b0>
# [01/29/2026 10:04:47 INFO 140651495421760] Scaling model computed with parameters:
#  {'stdev_label':
# [30.504099]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [2.7398677]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [55.]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [5.025]
# <NDArray 1 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [01/29/2026 10:04:47 INFO 140651495421760] nvidia-smi: took 0.032 seconds to run.
# [01/29/2026 10:04:47 INFO 140651495421760] nvidia-smi identified 0 GPUs.
# [01/29/2026 10:04:47 INFO 140651495421760] Number of GPUs being used: 0
# #metrics {"StartTime": 1769681087.249231, "EndTime": 1769681087.2492614, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2026-01-29 10:04:47.275] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 25, "num_examples": 2, "num_bytes": 240}
# #metrics {"StartTime": 1769681087.275305, "EndTime": 1769681087.2753701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9930688142776489, "count": 1, "min": 0.9930688142776489, "max": 0.9930688142776489}}}
# #metrics {"StartTime": 1769681087.275521, "EndTime": 1769681087.2755396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0159642696380615, "count": 1, "min": 1.0159642696380615, "max": 1.0159642696380615}}}
# #metrics {"StartTime": 1769681087.2756176, "EndTime": 1769681087.2756305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9453150033950806, "count": 1, "min": 0.9453150033950806, "max": 0.9453150033950806}}}
# #metrics {"StartTime": 1769681087.276924, "EndTime": 1769681087.2769375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.061589002609253, "count": 1, "min": 1.061589002609253, "max": 1.061589002609253}}}
# #metrics {"StartTime": 1769681087.2769792, "EndTime": 1769681087.2769897, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9353050589561462, "count": 1, "min": 0.9353050589561462, "max": 0.9353050589561462}}}
# #metrics {"StartTime": 1769681087.2770576, "EndTime": 1769681087.27707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.031520962715149, "count": 1, "min": 1.031520962715149, "max": 1.031520962715149}}}
# #metrics {"StartTime": 1769681087.277111, "EndTime": 1769681087.2771215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0160952806472778, "count": 1, "min": 1.0160952806472778, "max": 1.0160952806472778}}}
# #metrics {"StartTime": 1769681087.2771587, "EndTime": 1769681087.2771683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0029754638671875, "count": 1, "min": 1.0029754638671875, "max": 1.0029754638671875}}}
# #metrics {"StartTime": 1769681087.2772539, "EndTime": 1769681087.2772686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9592456817626953, "count": 1, "min": 0.9592456817626953, "max": 0.9592456817626953}}}
# #metrics {"StartTime": 1769681087.2773366, "EndTime": 1769681087.2773485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9563990831375122, "count": 1, "min": 0.9563990831375122, "max": 0.9563990831375122}}}
# #metrics {"StartTime": 1769681087.27739, "EndTime": 1769681087.2773998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0026535987854004, "count": 1, "min": 1.0026535987854004, "max": 1.0026535987854004}}}
# #metrics {"StartTime": 1769681087.2774675, "EndTime": 1769681087.2774806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9903910160064697, "count": 1, "min": 0.9903910160064697, "max": 0.9903910160064697}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.9930688142776489
# [01/29/2026 10:04:47 INFO 140651495421760] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.9353050589561462
# [01/29/2026 10:04:47 INFO 140651495421760] Epoch 0: Loss improved. Updating best model
# [01/29/2026 10:04:47 INFO 140651495421760] Saving model for epoch: 0
# [01/29/2026 10:04:47 INFO 140651495421760] Saved checkpoint to "/tmp/tmp64rtv_25/mx-mod-0000.params"
# [01/29/2026 10:04:47 INFO 140651495421760] #progress_metric: host=algo-1, completed 16.666666666666668 % of epochs
# #metrics {"StartTime": 1769681087.2494867, "EndTime": 1769681087.2855213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #throughput_metric: host=algo-1, train throughput=138.35007883469783 records/second
# [2026-01-29 10:04:47.299] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 14, "num_examples": 2, "num_bytes": 240}
# #metrics {"StartTime": 1769681087.2999098, "EndTime": 1769681087.2999609, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9880958795547485, "count": 1, "min": 0.9880958795547485, "max": 0.9880958795547485}}}
# #metrics {"StartTime": 1769681087.3000736, "EndTime": 1769681087.3000872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0109914541244507, "count": 1, "min": 1.0109914541244507, "max": 1.0109914541244507}}}
# #metrics {"StartTime": 1769681087.3001356, "EndTime": 1769681087.3001463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.990869402885437, "count": 1, "min": 0.990869402885437, "max": 0.990869402885437}}}
# #metrics {"StartTime": 1769681087.30018, "EndTime": 1769681087.3001883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0098214149475098, "count": 1, "min": 1.0098214149475098, "max": 1.0098214149475098}}}
# #metrics {"StartTime": 1769681087.3002205, "EndTime": 1769681087.3002295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8411474227905273, "count": 1, "min": 0.8411474227905273, "max": 0.8411474227905273}}}
# #metrics {"StartTime": 1769681087.300261, "EndTime": 1769681087.300269, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.026548147201538, "count": 1, "min": 1.026548147201538, "max": 1.026548147201538}}}
# #metrics {"StartTime": 1769681087.301483, "EndTime": 1769681087.3014936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0111223459243774, "count": 1, "min": 1.0111223459243774, "max": 1.0111223459243774}}}
# #metrics {"StartTime": 1769681087.3015559, "EndTime": 1769681087.3015666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9980025887489319, "count": 1, "min": 0.9980025887489319, "max": 0.9980025887489319}}}
# #metrics {"StartTime": 1769681087.3016903, "EndTime": 1769681087.3017092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0587036609649658, "count": 1, "min": 1.0587036609649658, "max": 1.0587036609649658}}}
# #metrics {"StartTime": 1769681087.3017485, "EndTime": 1769681087.3017588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0558571815490723, "count": 1, "min": 1.0558571815490723, "max": 1.0558571815490723}}}
# #metrics {"StartTime": 1769681087.301814, "EndTime": 1769681087.301825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9031956195831299, "count": 1, "min": 0.9031956195831299, "max": 0.9031956195831299}}}
# #metrics {"StartTime": 1769681087.3018596, "EndTime": 1769681087.301866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8909337520599365, "count": 1, "min": 0.8909337520599365, "max": 0.8909337520599365}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.9880958795547485
# [01/29/2026 10:04:47 INFO 140651495421760] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.8411474227905273
# [01/29/2026 10:04:47 INFO 140651495421760] Epoch 1: Loss improved. Updating best model
# [01/29/2026 10:04:47 INFO 140651495421760] Saving model for epoch: 1
# [01/29/2026 10:04:47 INFO 140651495421760] Saved checkpoint to "/tmp/tmp6k1d5zqs/mx-mod-0000.params"
# [01/29/2026 10:04:47 INFO 140651495421760] #progress_metric: host=algo-1, completed 33.333333333333336 % of epochs
# #metrics {"StartTime": 1769681087.285795, "EndTime": 1769681087.3089173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #throughput_metric: host=algo-1, train throughput=214.69175487807374 records/second
# [2026-01-29 10:04:47.328] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 18, "num_examples": 2, "num_bytes": 240}
# #metrics {"StartTime": 1769681087.3283362, "EndTime": 1769681087.3283858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9831230044364929, "count": 1, "min": 0.9831230044364929, "max": 0.9831230044364929}}}
# #metrics {"StartTime": 1769681087.3284729, "EndTime": 1769681087.328487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0060185194015503, "count": 1, "min": 1.0060185194015503, "max": 1.0060185194015503}}}
# #metrics {"StartTime": 1769681087.3285613, "EndTime": 1769681087.3285751, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9858964681625366, "count": 1, "min": 0.9858964681625366, "max": 0.9858964681625366}}}
# #metrics {"StartTime": 1769681087.328616, "EndTime": 1769681087.3286262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0048484802246094, "count": 1, "min": 1.0048484802246094, "max": 1.0048484802246094}}}
# #metrics {"StartTime": 1769681087.3287077, "EndTime": 1769681087.328719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7416894435882568, "count": 1, "min": 0.7416894435882568, "max": 0.7416894435882568}}}
# #metrics {"StartTime": 1769681087.3287892, "EndTime": 1769681087.3288016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7541539072990417, "count": 1, "min": 0.7541539072990417, "max": 0.7541539072990417}}}
# #metrics {"StartTime": 1769681087.32884, "EndTime": 1769681087.3288465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8606787323951721, "count": 1, "min": 0.8606787323951721, "max": 0.8606787323951721}}}
# #metrics {"StartTime": 1769681087.3288753, "EndTime": 1769681087.3288832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8235906958580017, "count": 1, "min": 0.8235906958580017, "max": 0.8235906958580017}}}
# #metrics {"StartTime": 1769681087.3289466, "EndTime": 1769681087.3289583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 1
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0183218717575073, "count": 1, "min": 1.0183218717575073, "max": 1.0183218717575073}}}
# #metrics {"StartTime": 1769681087.330048, "EndTime": 1769681087.3300564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.020155906677246, "count": 1, "min": 1.020155906677246, "max": 1.020155906677246}}}
# #metrics {"StartTime": 1769681087.3300815, "EndTime": 1769681087.33009, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9667985439300537, "count": 1, "min": 0.9667985439300537, "max": 0.9667985439300537}}}
# #metrics {"StartTime": 1769681087.3301246, "EndTime": 1769681087.330134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9646629095077515, "count": 1, "min": 0.9646629095077515, "max": 0.9646629095077515}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.9831230044364929
# [01/29/2026 10:04:47 INFO 140651495421760] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.7416894435882568
# [01/29/2026 10:04:47 INFO 140651495421760] Epoch 2: Loss improved. Updating best model
# [01/29/2026 10:04:47 INFO 140651495421760] Saving model for epoch: 2
# [01/29/2026 10:04:47 INFO 140651495421760] Saved checkpoint to "/tmp/tmptxp21gjv/mx-mod-0000.params"
# [01/29/2026 10:04:47 INFO 140651495421760] #progress_metric: host=algo-1, completed 50.0 % of epochs
# #metrics {"StartTime": 1769681087.3092506, "EndTime": 1769681087.3367145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Total Batches Seen": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Max Records Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #throughput_metric: host=algo-1, train throughput=181.28437194747715 records/second
# [2026-01-29 10:04:47.350] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 13, "num_examples": 2, "num_bytes": 240}
# #metrics {"StartTime": 1769681087.3507807, "EndTime": 1769681087.350829, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9781500697135925, "count": 1, "min": 0.9781500697135925, "max": 0.9781500697135925}}}
# #metrics {"StartTime": 1769681087.3508844, "EndTime": 1769681087.3508961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.00104558467865, "count": 1, "min": 1.00104558467865, "max": 1.00104558467865}}}
# #metrics {"StartTime": 1769681087.350976, "EndTime": 1769681087.3509893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9809235334396362, "count": 1, "min": 0.9809235334396362, "max": 0.9809235334396362}}}
# #metrics {"StartTime": 1769681087.3510337, "EndTime": 1769681087.3510442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.999875545501709, "count": 1, "min": 0.999875545501709, "max": 0.999875545501709}}}
# #metrics {"StartTime": 1769681087.351078, "EndTime": 1769681087.351088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6422315239906311, "count": 1, "min": 0.6422315239906311, "max": 0.6422315239906311}}}
# #metrics {"StartTime": 1769681087.351143, "EndTime": 1769681087.351153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.654695987701416, "count": 1, "min": 0.654695987701416, "max": 0.654695987701416}}}
# #metrics {"StartTime": 1769681087.3511786, "EndTime": 1769681087.351188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7612208127975464, "count": 1, "min": 0.7612208127975464, "max": 0.7612208127975464}}}
# #metrics {"StartTime": 1769681087.3512392, "EndTime": 1769681087.3512497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.724132776260376, "count": 1, "min": 0.724132776260376, "max": 0.724132776260376}}}
# #metrics {"StartTime": 1769681087.3513, "EndTime": 1769681087.3513105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0424351692199707, "count": 1, "min": 1.0424351692199707, "max": 1.0424351692199707}}}
# #metrics {"StartTime": 1769681087.351375, "EndTime": 1769681087.3513868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9643154144287109, "count": 1, "min": 0.9643154144287109, "max": 0.9643154144287109}}}
# ...
# [01/29/2026 10:04:47 INFO 140651495421760] #throughput_metric: host=algo-1, train throughput=224.2319782734213 records/second
# [2026-01-29 10:04:47.395] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 13, "num_examples": 2, "num_bytes": 240}
# #metrics {"StartTime": 1769681087.3956332, "EndTime": 1769681087.3956785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9682042598724365, "count": 1, "min": 0.9682042598724365, "max": 0.9682042598724365}}}
# #metrics {"StartTime": 1769681087.395736, "EndTime": 1769681087.3957486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9910998344421387, "count": 1, "min": 0.9910998344421387, "max": 0.9910998344421387}}}
# #metrics {"StartTime": 1769681087.3957832, "EndTime": 1769681087.3957925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.970977783203125, "count": 1, "min": 0.970977783203125, "max": 0.970977783203125}}}
# #metrics {"StartTime": 1769681087.395864, "EndTime": 1769681087.3958766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9899297952651978, "count": 1, "min": 0.9899297952651978, "max": 0.9899297952651978}}}
# #metrics {"StartTime": 1769681087.3959131, "EndTime": 1769681087.3959222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4433158040046692, "count": 1, "min": 0.4433158040046692, "max": 0.4433158040046692}}}
# #metrics {"StartTime": 1769681087.3959596, "EndTime": 1769681087.395968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4557802677154541, "count": 1, "min": 0.4557802677154541, "max": 0.4557802677154541}}}
# #metrics {"StartTime": 1769681087.3960032, "EndTime": 1769681087.3960128, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5623051524162292, "count": 1, "min": 0.5623051524162292, "max": 0.5623051524162292}}}
# #metrics {"StartTime": 1769681087.3960433, "EndTime": 1769681087.3960526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5252171158790588, "count": 1, "min": 0.5252171158790588, "max": 0.5252171158790588}}}
# #metrics {"StartTime": 1769681087.3961077, "EndTime": 1769681087.3961172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0324894189834595, "count": 1, "min": 1.0324894189834595, "max": 1.0324894189834595}}}
# #metrics {"StartTime": 1769681087.3961577, "EndTime": 1769681087.3961673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9543696641921997, "count": 1, "min": 0.9543696641921997, "max": 0.9543696641921997}}}
# #metrics {"StartTime": 1769681087.3962264, "EndTime": 1769681087.3962362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9620735049247742, "count": 1, "min": 0.9620735049247742, "max": 0.9620735049247742}}}
# #metrics {"StartTime": 1769681087.3962722, "EndTime": 1769681087.3962786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9450381994247437, "count": 1, "min": 0.9450381994247437, "max": 0.9450381994247437}}}
# #metrics {"StartTime": 1769681087.3963127, "EndTime": 1769681087.3963213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4546836316585541, "count": 1, "min": 0.4546836316585541, "max": 0.4546836316585541}}}
# #metrics {"StartTime": 1769681087.3963552, "EndTime": 1769681087.3963637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.48831039667129517, "count": 1, "min": 0.48831039667129517, "max": 0.48831039667129517}}}
# #metrics {"StartTime": 1769681087.396393, "EndTime": 1769681087.3964016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.45277875661849976, "count": 1, "min": 0.45277875661849976, "max": 0.45277875661849976}}}
# #metrics {"StartTime": 1769681087.396436, "EndTime": 1769681087.396445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.49636971950531006, "count": 1, "min": 0.49636971950531006, "max": 0.49636971950531006}}}
# #metrics {"StartTime": 1769681087.3965018, "EndTime": 1769681087.3965123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9266614317893982, "count": 1, "min": 0.9266614317893982, "max": 0.9266614317893982}}}
# #metrics {"StartTime": 1769681087.396554, "EndTime": 1769681087.3965642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9856424927711487, "count": 1, "min": 0.9856424927711487, "max": 0.9856424927711487}}}
# #metrics {"StartTime": 1769681087.3966284, "EndTime": 1769681087.3966386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9578074216842651, "count": 1, "min": 0.9578074216842651, "max": 0.9578074216842651}}}
# #metrics {"StartTime": 1769681087.3966992, "EndTime": 1769681087.3967083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9546982049942017, "count": 1, "min": 0.9546982049942017, "max": 0.9546982049942017}}}
# #metrics {"StartTime": 1769681087.3967414, "EndTime": 1769681087.3967497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5191452503204346, "count": 1, "min": 0.5191452503204346, "max": 0.5191452503204346}}}
# #metrics {"StartTime": 1769681087.3967984, "EndTime": 1769681087.3968077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5384092330932617, "count": 1, "min": 0.5384092330932617, "max": 0.5384092330932617}}}
# #metrics {"StartTime": 1769681087.396867, "EndTime": 1769681087.3968778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.45677483081817627, "count": 1, "min": 0.45677483081817627, "max": 0.45677483081817627}}}
# #metrics {"StartTime": 1769681087.3969157, "EndTime": 1769681087.3969235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5715634226799011, "count": 1, "min": 0.5715634226799011, "max": 0.5715634226799011}}}
# #metrics {"StartTime": 1769681087.396957, "EndTime": 1769681087.3969646, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9598278999328613, "count": 1, "min": 0.9598278999328613, "max": 0.9598278999328613}}}
# #metrics {"StartTime": 1769681087.396994, "EndTime": 1769681087.3970025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.007187843322754, "count": 1, "min": 1.007187843322754, "max": 1.007187843322754}}}
# #metrics {"StartTime": 1769681087.397061, "EndTime": 1769681087.397071, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9924821853637695, "count": 1, "min": 0.9924821853637695, "max": 0.9924821853637695}}}
# #metrics {"StartTime": 1769681087.3971102, "EndTime": 1769681087.397119, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9836757779121399, "count": 1, "min": 0.9836757779121399, "max": 0.9836757779121399}}}
# #metrics {"StartTime": 1769681087.3971527, "EndTime": 1769681087.3971608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9510902166366577, "count": 1, "min": 0.9510902166366577, "max": 0.9510902166366577}}}
# #metrics {"StartTime": 1769681087.3971906, "EndTime": 1769681087.3971994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9518405199050903, "count": 1, "min": 0.9518405199050903, "max": 0.9518405199050903}}}
# #metrics {"StartTime": 1769681087.397229, "EndTime": 1769681087.3972378, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0420345067977905, "count": 1, "min": 1.0420345067977905, "max": 1.0420345067977905}}}
# #metrics {"StartTime": 1769681087.3972938, "EndTime": 1769681087.397304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0555214881896973, "count": 1, "min": 1.0555214881896973, "max": 1.0555214881896973}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, epoch=5, train absolute_loss_objective <loss>=0.9682042598724365
# [01/29/2026 10:04:47 INFO 140651495421760] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=absolute_loss_objective, value=0.4433158040046692
# [01/29/2026 10:04:47 INFO 140651495421760] Epoch 5: Loss improved. Updating best model
# [01/29/2026 10:04:47 INFO 140651495421760] Saving model for epoch: 5
# [01/29/2026 10:04:47 INFO 140651495421760] Saved checkpoint to "/tmp/tmp0u1y2agc/mx-mod-0000.params"
# [01/29/2026 10:04:47 INFO 140651495421760] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1769681087.3817441, "EndTime": 1769681087.4034622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 39.0, "count": 1, "min": 39, "max": 39}, "Total Batches Seen": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Max Records Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/29/2026 10:04:47 INFO 140651495421760] #throughput_metric: host=algo-1, train throughput=229.08677794284716 records/second
# [01/29/2026 10:04:47 WARNING 140651495421760] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/29/2026 10:04:47 WARNING 140651495421760] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2026-01-29 10:04:47.404] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 0, "num_examples": 1, "num_bytes": 192}
# [2026-01-29 10:04:47.408] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 2, "num_examples": 2, "num_bytes": 240}
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('absolute_loss_objective', 11.482820892333985)
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('mse', 138.188623046875)
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('absolute_loss', 11.482820892333985)
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('rmse', 11.755365713021224)
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('r2', 0.8513077538949954)
# [01/29/2026 10:04:47 INFO 140651495421760] #train_score (algo-1) : ('mae', 11.482820892333985)
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=11.482820892333985
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train mse <loss>=138.188623046875
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train absolute_loss <loss>=11.482820892333985
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train rmse <loss>=11.755365713021224
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train r2 <loss>=0.8513077538949954
# [01/29/2026 10:04:47 INFO 140651495421760] #quality_metric: host=algo-1, train mae <loss>=11.482820892333985
# [01/29/2026 10:04:47 INFO 140651495421760] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [01/29/2026 10:04:47 INFO 140651495421760] Saved checkpoint to "/tmp/tmprjf0ng_q/mx-mod-0000.params"
# [01/29/2026 10:04:47 INFO 140651495421760] Test data is not provided.
# #metrics {"StartTime": 1769681087.1430707, "EndTime": 1769681087.4136786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 105.44347763061523, "count": 1, "min": 105.44347763061523, "max": 105.44347763061523}, "epochs": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "check_early_stopping.time": {"sum": 4.891633987426758, "count": 6, "min": 0.751495361328125, "max": 0.8966922760009766}, "update.time": {"sum": 139.95099067687988, "count": 6, "min": 19.848108291625977, "max": 33.481597900390625}, "finalize.time": {"sum": 6.077766418457031, "count": 1, "min": 6.077766418457031, "max": 6.077766418457031}, "setuptime": {"sum": 1.7783641815185547, "count": 1, "min": 1.7783641815185547, "max": 1.7783641815185547}, "totaltime": {"sum": 363.8343811035156, "count": 1, "min": 363.8343811035156, "max": 363.8343811035156}}}
#
# 2026-01-29 10:05:04 Uploading - Uploading generated training model
# 2026-01-29 10:05:04 Completed - Training job completed
# Training seconds: 135
# Billable seconds: 135

# %%
# deploy the model
linear_regressor = linear.deploy(initial_instance_count=1,instance_type="ml.m5.xlarge")
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2026-01-29-10-21-43-796
# INFO:sagemaker:Creating endpoint-config with name linear-learner-2026-01-29-10-21-43-796
# INFO:sagemaker:Creating endpoint with name linear-learner-2026-01-29-10-21-43-796
# -------!

# %%
linear_regressor.serializer = sagemaker.serializers.CSVSerializer()
linear_regressor.deserializer = sagemaker.deserializers.JSONDeserializer()

# %%
#predictions 
results = linear_regressor.predict(X_test)
results
# Out:
# {'predictions': [{'score': 37.92646408081055},
#   {'score': 74.64373779296875},
#   {'score': 75.37808990478516},
#   {'score': 32.05169677734375},
#   {'score': 36.45777130126953}]}

# %%
predictions = np.array([i["score"] for i in results["predictions"]])
predictions
# Out:
# array([37.92646408, 74.64373779, 75.3780899 , 32.05169678, 36.4577713 ])
